# %%
# %matplotlib inline

# %%
import numpy as np
import scipy.special as scsp
import matplotlib.pyplot as plt

# %%
x=np.arange(0,10,0.01)

# %%
J0=scsp.jv(0,x)

# %%
plt.rcParams['font.size'] = 12
plt.rcParams['font.family'] = "Serif"

# %%
fig=plt.figure()
fsize=14
ax1=fig.add_subplot(111)

ax1.plot(x,J0,label="$J_{0}(x)$")

ax1.set_title("Bessel function $J_{0}(x)$")
ax1.set_xlabel("x",fontsize=fsize)
ax1.set_ylabel("$J_{0}(x)$",fontsize=fsize)
ax1.grid()
ax1.legend(loc=0).get_frame().set_facecolor('#FFFFFF')

# %%
I0=scsp.iv(0,x)
K0=scsp.kv(0,x)

# %%
fig=plt.figure()
fsize=14
ax1=fig.add_subplot(111)

ax1.plot(x,I0,label="$I_{0}(x)$")
ax1.plot(x,K0,label="$K_{0}(x)$")

ax1.set_xlim(0,1)
ax1.set_ylim(0,5)

ax1.set_title("Modified Bessel Function of order 0")
ax1.set_xlabel("x",fontsize=fsize)
ax1.set_ylabel("$I_{0}(x), K_{0}(x)$",fontsize=fsize)
ax1.grid()
ax1.legend(loc=0).get_frame().set_facecolor('#FFFFFF')

# %%
fig=plt.figure()
fsize=14
ax1=fig.add_axes((0,0,1,0.5))
ax2=fig.add_axes((0,0.5,1,0.5),sharex=ax1)

ax1.plot(x,I0,label="$I_{0}(x)$")
ax2.plot(x,K0,label="$K_{0}(x)$")

ax1.set_xlim(0,1)
ax1.set_ylim(1,1.4)

ax2.tick_params(labelbottom="off")
ax2.set_yticks(np.arange(1,5,1))
ax1.set_yticks(np.arange(1,1.4,0.1))
ax2.set_title("Modified Bessel Function")
ax2.set_ylabel("$K_0(x)$",fontsize=fsize)
ax1.set_ylabel("$I_0(x)$",fontsize=fsize)
ax1.set_xlabel("$x$",fontsize=fsize)
ax1.grid()
ax2.grid()
